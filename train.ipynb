# %%
import torch
# from ultralytics import YOLO

# %%
# ตรวจสอบว่าใช้ GPU ได้หรือไม่
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# โหลดโมเดล YOLOv8 สำหรับ Object Detection
# เลือกโมเดลได้: yolov8n.pt (เล็ก), yolov8s.pt, yolov8m.pt, yolov8l.pt, yolov8x.pt (ใหญ่สุด)
model = YOLO('yolov8n.pt')

# เทรนโมเดล
dataset_path = "/content/dataset"  # แก้ path ให้เป็น dataset ของคุณ (ที่ต้องมี data.yaml)

model.train(
    data=f"{dataset_path}/data.yaml",  # ไฟล์ data.yaml ต้องกำหนด path ของ train/val และ class
    epochs=50,             # จำนวนรอบการเทรน
    batch=16,              # batch size
    imgsz=640,             # ขนาด input image
    device=0 if device=='cuda' else 'cpu',  # เลือก GPU ถ้ามี
    name="yolov8_object_detection"  # ตั้งชื่อ experiment
)

# ประเมินโมเดล
metrics = model.val()
print(metrics)

# ทดสอบกับภาพตัวอย่าง
test_img = f"{dataset_path}/test/images/sample.jpg"  # แก้ path เป็นภาพที่ต้องการ
results = model(test_img)

# แสดงผลลัพธ์
results.show()
